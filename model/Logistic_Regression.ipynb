# %% [markdown]
# **ML ASSIGNMENT2- ARUN SINGH SHAH**
#
# ARUN SINGH SHAH- 2025aa05340@wilp.bits-pilani.ac.in

# %% [markdown]
# **Logistic Regression on Credit Card Fraud Detection**

# %% [markdown]
# The data is related to credit card clients of a banking institution. It contains demographic information, credit limit details, repayment history, and past bill and payment records. The objective is to identify whether a client will default on credit card payment in the next month. This is a binary classification problem, where the outcome is classified as default (yes) or non-default (no).

# %%
#Import Libraries
import os;
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
credit_data = pd.read_excel(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls",
    header=1
)

credit_data.columns = credit_data.columns.str.strip()

if "default payment next month" in credit_data.columns:
    credit_data.rename(
        columns={"default payment next month": "target"},
        inplace=True
    )
elif "default.payment.next.month" in credit_data.columns:
    credit_data.rename(
        columns={"default.payment.next.month": "target"},
        inplace=True
    )

credit_train, credit_test = train_test_split(
    credit_data,
    test_size=0.2,
    random_state=42,
    stratify=credit_data["target"]
)

print("Train shape:", credit_train.shape)
print("Test shape:", credit_test.shape)

# Save train and test datasets
credit_train.to_csv("credit_train.csv", index=False)
credit_test.to_csv("credit_test.csv", index=False)
# Out:
# Train shape: (24000, 25)
# Test shape: (6000, 25)

# %%
# Quick Look on Train dataset - Display first 5 rows of train dataset
credit_train.head()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 22788  22789     160000    2          2         2   33      2      2      3
# 29006  29007     150000    2          1         2   34      1     -1     -1
# 16950  16951      10000    1          2         1   50      1      2      0
# 22280  22281     220000    2          1         2   29      0      0      0
# 11346  11347     310000    2          1         2   32      1     -2     -1
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 22788      2  ...     164310     162681     163005     15000         0
# 29006     -2  ...          0          0          0        53         0
# 16950      0  ...       8067       8227       8400         2      1281
# 22280      0  ...     218513     131660     134346      9100      9000
# 11346      0  ...        326       -235       -235         0       326
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  target
# ...

# %%
#Get Dataset Info for Train data
credit_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24000 entries, 22788 to 27126
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         24000 non-null  int64
#  1   LIMIT_BAL  24000 non-null  int64
#  2   SEX        24000 non-null  int64
#  3   EDUCATION  24000 non-null  int64
#  4   MARRIAGE   24000 non-null  int64
#  5   AGE        24000 non-null  int64
#  6   PAY_0      24000 non-null  int64
#  7   PAY_2      24000 non-null  int64
#  8   PAY_3      24000 non-null  int64
#  9   PAY_4      24000 non-null  int64
#  10  PAY_5      24000 non-null  int64
#  11  PAY_6      24000 non-null  int64
#  12  BILL_AMT1  24000 non-null  int64
#  13  BILL_AMT2  24000 non-null  int64
#  14  BILL_AMT3  24000 non-null  int64
#  15  BILL_AMT4  24000 non-null  int64
#  16  BILL_AMT5  24000 non-null  int64
#  17  BILL_AMT6  24000 non-null  int64
#  18  PAY_AMT1   24000 non-null  int64
#  19  PAY_AMT2   24000 non-null  int64
# ...

# %%
#Shape of Train Dataset
credit_train.shape
# Out:
# (24000, 25)

# %%
#Missing Value from Train Dataset
credit_train.isnull().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# target       0
# dtype: int64

# %%
# Quick look at TEST dataset
credit_test.head()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 6907    6908      50000    1          2         2   46     -1     -1     -1
# 24575  24576     150000    1          1         1   31     -1     -1     -2
# 26766  26767      50000    1          2         2   25      0      0      0
# 2156    2157     290000    2          1         2   25      0      0      0
# 3179    3180     500000    2          2         1   27     -2     -2     -2
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 6907      -1  ...       2650       3320       2764     26060         0
# 24575     -2  ...          0          0      11694         0         0
# 26766      0  ...      49949      50479      50702      1800      1844
# 2156       0  ...     248801     241983     230925     15000     10500
# 3179      -2  ...      10000      10000      10000      9983     13587
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  target
# ...

# %%
# Get info of TEST dataset
credit_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6000 entries, 6907 to 24399
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         6000 non-null   int64
#  1   LIMIT_BAL  6000 non-null   int64
#  2   SEX        6000 non-null   int64
#  3   EDUCATION  6000 non-null   int64
#  4   MARRIAGE   6000 non-null   int64
#  5   AGE        6000 non-null   int64
#  6   PAY_0      6000 non-null   int64
#  7   PAY_2      6000 non-null   int64
#  8   PAY_3      6000 non-null   int64
#  9   PAY_4      6000 non-null   int64
#  10  PAY_5      6000 non-null   int64
#  11  PAY_6      6000 non-null   int64
#  12  BILL_AMT1  6000 non-null   int64
#  13  BILL_AMT2  6000 non-null   int64
#  14  BILL_AMT3  6000 non-null   int64
#  15  BILL_AMT4  6000 non-null   int64
#  16  BILL_AMT5  6000 non-null   int64
#  17  BILL_AMT6  6000 non-null   int64
#  18  PAY_AMT1   6000 non-null   int64
#  19  PAY_AMT2   6000 non-null   int64
# ...

# %%
# Shape of TEST dataset
credit_test.shape
# Out:
# (6000, 25)

# %%
# Missing values in TEST dataset
credit_test.isnull().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# target       0
# dtype: int64

# %%
# Describe TEST dataset
credit_train.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  24000.000000    24000.000000  24000.000000  24000.000000  24000.000000
# mean   14973.683417   167364.666667      1.604750      1.853792      1.552875
# std     8641.664947   129511.313151      0.488915      0.792375      0.521903
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7513.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    14966.000000   140000.000000      2.000000      2.000000      2.000000
# 75%    22438.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  24000.000000  24000.000000  24000.000000  24000.000000  24000.000000
# mean      35.432625     -0.014125     -0.134083     -0.166917     -0.221333
# ...

# %%
# Describe TEST dataset
credit_test.describe()
# Out:
#                  ID      LIMIT_BAL          SEX    EDUCATION     MARRIAGE  \
# count   6000.000000    6000.000000  6000.000000  6000.000000  6000.000000
# mean   15107.766333  167962.946667     1.599667     1.850500     1.547833
# std     8734.831845  130698.538357     0.490007     0.782252     0.522262
# min        2.000000   10000.000000     1.000000     0.000000     0.000000
# 25%     7448.000000   50000.000000     1.000000     1.000000     1.000000
# 50%    15115.500000  140000.000000     2.000000     2.000000     2.000000
# 75%    22758.500000  240000.000000     2.000000     2.000000     2.000000
# max    29997.000000  800000.000000     2.000000     6.000000     3.000000
#
#                AGE        PAY_0        PAY_2        PAY_3        PAY_4  ...  \
# count  6000.000000  6000.000000  6000.000000  6000.000000  6000.000000  ...
# mean     35.697000    -0.027000    -0.132500    -0.163333    -0.218000  ...
# ...

# %%
# Find correlation between features
plt.figure(figsize=(20, 20))
sns.heatmap(
    credit_train.corr(numeric_only=True, method='pearson'),
    cmap='viridis',
    vmin=-1,
    vmax=1,
    annot=True,
    square=True
)
plt.show()

# %%
# Handle categorical features

categorical_cols = credit_train.select_dtypes(include='object').columns.tolist()

# Remove target column if present
if 'target' in categorical_cols:
    categorical_cols.remove('target')

print(f"Identified categorical columns (excluding 'target'): {categorical_cols}")
# Out:
# Identified categorical columns (excluding 'target'): []

# %%
# Apply One Hot Encoding to convert categorical variables into numerical format

credit_train_encoded = pd.get_dummies(
    credit_train,
    columns=categorical_cols,
    drop_first=False
)

credit_test_encoded = pd.get_dummies(
    credit_test,
    columns=categorical_cols,
    drop_first=False
)

# Align columns between train and test datasets
aligned_columns = credit_train_encoded.columns.tolist()

# Reindex test set to match training set columns
credit_test_encoded = credit_test_encoded.reindex(
    columns=aligned_columns,
    fill_value=0
)

print("Shape of credit_train_encoded:", credit_train_encoded.shape)
print("Shape of credit_test_encoded:", credit_test_encoded.shape)

print("\nFirst 5 rows of credit_train_encoded:")
print(credit_train_encoded.head())

print("\nFirst 5 rows of credit_test_encoded:")
print(credit_test_encoded.head())
# Out:
# Shape of credit_train_encoded: (24000, 25)
# Shape of credit_test_encoded: (6000, 25)
#
# First 5 rows of credit_train_encoded:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 22788  22789     160000    2          2         2   33      2      2      3
# 29006  29007     150000    2          1         2   34      1     -1     -1
# 16950  16951      10000    1          2         1   50      1      2      0
# 22280  22281     220000    2          1         2   29      0      0      0
# 11346  11347     310000    2          1         2   32      1     -2     -1
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 22788      2  ...     164310     162681     163005     15000         0
# 29006     -2  ...          0          0          0        53         0
# 16950      0  ...       8067       8227       8400         2      1281
# 22280      0  ...     218513     131660     134346      9100      9000
# ...

# %%
# Prepare Feature and Target Sets

X_train = credit_train_encoded.drop('target', axis=1)
y_train = credit_train_encoded['target']

X_test = credit_test_encoded.drop('target', axis=1)
y_test = credit_test_encoded['target']

print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (24000, 24)
# Shape of y_train: (24000,)
# Shape of X_test: (6000, 24)
# Shape of y_test: (6000,)

# %%
# Target is already binary (0 = No Default, 1 = Default)
# No transformation needed

print("Value counts of y_train:")
print(y_train.value_counts())

print("\nValue counts of y_test:")
print(y_test.value_counts())
# Out:
# Value counts of y_train:
# target
# 0    18691
# 1     5309
# Name: count, dtype: int64
#
# Value counts of y_test:
# target
# 0    4673
# 1    1327
# Name: count, dtype: int64

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    matthews_corrcoef,
    roc_auc_score,
    confusion_matrix
)

def evaluate_model(model, X_test, y_test, model_name, X_test_scaled=None):
    """
    Evaluate a classification model and return metrics
    """

    # Use scaled data if provided (for Logistic, KNN, Naive Bayes)
    X_eval = X_test_scaled if X_test_scaled is not None else X_test

    # Predictions
    y_pred = model.predict(X_eval)

    # Probabilities for AUC
    if hasattr(model, "predict_proba"):
        y_pred_proba = model.predict_proba(X_eval)[:, 1]
        auc = roc_auc_score(y_test, y_pred_proba)
    else:
        auc = 0.0

    # Metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y_test, y_pred)

    cm = confusion_matrix(y_test, y_pred)

    return {
        "model_name": model_name,
        "accuracy": round(accuracy, 4),
        "auc": round(auc, 4),
        "precision": round(precision, 4),
        "recall": round(recall, 4),
        "f1": round(f1, 4),
        "mcc": round(mcc, 4),
        "confusion_matrix": cm
    }

# %%
# Initialize and Train Logistic Regression Model (Credit Card Dataset)

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Initialize scaler
scaler = StandardScaler()

# Scale training and test data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize Logistic Regression model
log_reg_model = LogisticRegression(
    max_iter=1000,
    random_state=42,
    n_jobs=-1
)

# Train the model
log_reg_model.fit(X_train_scaled, y_train)

# Evaluate Logistic Regression model
log_reg_results = evaluate_model(
    model=log_reg_model,
    X_test=X_test,
    y_test=y_test,
    model_name="Logistic Regression",
    X_test_scaled=X_test_scaled
)

print("Logistic Regression model trained successfully.")
# Out:
# Logistic Regression model trained successfully.

# %%
# Create Confusion Matrix for Logistic Regression

import matplotlib.pyplot as plt
import seaborn as sns

# Extract confusion matrix from logistic regression results
cm = log_reg_results['confusion_matrix']

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Greens',        # changed color (not Blues)
    cbar=False,
    xticklabels=['No Default', 'Default'],
    yticklabels=['No Default', 'Default']
)

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix – Logistic Regression (Credit Card Default)')
plt.show()

# %%
# Print Evaluation of Logistic Regression Model

print("Evaluation of Logistic Regression Model:\n")

print(f"Accuracy: {float(log_reg_results['accuracy']):.4f}")
print(f"AUC Score: {float(log_reg_results['auc']):.4f}")
print(f"Precision: {float(log_reg_results['precision']):.4f}")
print(f"Recall: {float(log_reg_results['recall']):.4f}")
print(f"F1 Score: {float(log_reg_results['f1']):.4f}")
print(f"Matthews Correlation Coefficient (MCC): {float(log_reg_results['mcc']):.4f}")
# Out:
# Evaluation of Logistic Regression Model:
#
# Accuracy: 0.8080
# AUC Score: 0.7078
# Precision: 0.6882
# Recall: 0.2411
# F1 Score: 0.3571
# Matthews Correlation Coefficient (MCC): 0.3261

# %%
import pandas as pd

# Make predictions on the scaled test set
y_pred_log_reg = log_reg_model.predict(X_test_scaled)

# Convert numerical predictions (0, 1) to meaningful labels
y_pred_labels = pd.Series(y_pred_log_reg).map({0: 'No Default', 1: 'Default'})

# Create submission DataFrame (target column)
submission_df = pd.DataFrame({'target': y_pred_labels})

# Save predictions to CSV
submission_filename = 'logistic_regression_predictions.csv'
submission_df.to_csv(submission_filename, index=False)

print(f"Prediction file '{submission_filename}' created successfully.")
print("First 5 rows of the prediction file:")
display(submission_df.head())
# Out:
# Prediction file 'logistic_regression_predictions.csv' created successfully.
# First 5 rows of the prediction file:
#        target
# 0  No Default
# 1  No Default
# 2  No Default
# 3  No Default
# 4  No Default
